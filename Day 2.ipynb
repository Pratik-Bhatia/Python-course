# %%
a=10
b=20
c=a+b;
d=a-b;
e=a*b;
f=a/b;
print(c)
print(d)
print(e)
print(f)
print(a==b)
print(a<=b)
print(a>=b)
print(a!=b)
# Out:
# 30
# -10
# 200
# 0.5
# False
# True
# False
# True

# %%
c=a+b
print(c)
# Out:
# 30

# %%
a+=b
print(a)
# Out:
# 30

# %%
a-=b
print(a)
# Out:
# 10

# %%
a*=b
print(a)
# Out:
# 200

# %%
a/=b
print(a)
# Out:
# 0.5

# %%
a=60
b=30
print('a=',a,":",bin(a),'b=',b,":",bin(b))
c=0
c=a&b;
print("result of and is",c,":",bin(c))
# Out:
# a= 60 : 0b111100 b= 30 : 0b11110
# result of and is 28 : 0b11100

# %%
list=[10]
c=list;
if c==[10,20]:
    print("true")
else:
    print("false")
# Out:
# false

# %%
count=0
while(count < 9):
    print('the count is:', count)
    count = count+1
print("good bye")
# Out:
# the count is: 0
# the count is: 1
# the count is: 2
# the count is: 3
# the count is: 4
# the count is: 5
# the count is: 6
# the count is: 7
# the count is: 8
# good bye
